# %% [raw]
# Kodumuzu jenerik hale getirmeden önce web sitesinin bir sayfası üzerinde
# kodlarımızı deniyoruz. Kodlarımız çalışıp başarılı olduktan sonra ikinci notebook da
# jenerik hale getireceğiz.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
 
#--| Setup
options = Options()
#options.add_argument("--headless")
#options.add_argument("--window-size=1980,1020")
browser = webdriver.Chrome(executable_path=r'C:/Users/Joseph Forest/Documents/web scrapping/chromedriver.exe', options=options)
#--| Parse or automation
url = "https://pillintrip.com/az_index/A"
browser.get(url)
time.sleep(2)
 
# Use Bs to Parse
soup = BeautifulSoup(browser.page_source, 'html.parser')
# Out:
# <ipython-input-11-e498918806d6>:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=r'C:/Users/Joseph Forest/Documents/web scrapping/chromedriver.exe', options=options)

# %%
soup
# Out:
# <html class="-webkit-"><head>
# <title>A-Z index</title>
# <meta charset="utf-8"/>
# <script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202202090102/reactive_library_fy2019.js"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=pillintrip.com&amp;callback=_gfp_s_&amp;client=ca-pub-8448027803139159"></script><script async="" src="/javascript/watch.js" type="text/javascript"></script><script id="google_shimpl" src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202202090102/show_ads_impl_fy2019.js"></script><script src="/frameworks/jquery-3.4.1.min.js"></script>
# <script defer="" src="/frameworks/prefixfree.min.js"></script>
# <link href="/style/images/apple-icon-57x57.png" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
liste = soup.find("div",{"class":"res_block_list"}).find_all("a")

# %%
liste[:5]
# Out:
# [<a href="/medicine/abseamed">Abseamed</a>,
#  <a href="/medicine/accutane">Accutane</a>,
#  <a href="/medicine/abilify-discmelt-oral">Abilify Discmelt (Oral)</a>,
#  <a href="/medicine/amuco-200">Amuco 200</a>,
#  <a href="/medicine/aerius">Aerius</a>]

# %%
links = []
for link in liste:
    links.append(link.get('href'))
links[:5]
# Out:
# ['/medicine/abseamed',
#  '/medicine/accutane',
#  '/medicine/abilify-discmelt-oral',
#  '/medicine/amuco-200',
#  '/medicine/aerius']

# %%
medicine = []
for link in liste:
    medicine.append(link.text)
medicine[:5]
# Out:
# ['Abseamed', 'Accutane', 'Abilify Discmelt (Oral)', 'Amuco 200', 'Aerius']

# %%
import pandas as pd

# %%
pd.DataFrame({'medicine':medicine, "links":links})
# Out:
#                    medicine                            links
# 0                  Abseamed               /medicine/abseamed
# 1                  Accutane               /medicine/accutane
# 2   Abilify Discmelt (Oral)  /medicine/abilify-discmelt-oral
# 3                 Amuco 200              /medicine/amuco-200
# 4                    Aerius                 /medicine/aerius
# ..                      ...                              ...
# 95             Adco-Talomil           /medicine/adco-talomil
# 96                  Artifen                /medicine/artifen
# 97                  Antafen                /medicine/antafen
# 98              A-Ferin Hot            /medicine/a-ferin-hot
# 99                 Algofren               /medicine/algofren
#
# [100 rows x 2 columns]

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
